# %%
# %%time
# %load_ext autoreload
# %autoreload 2

import heapq
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

biz_name = 'Starbucks'
reviews = pd.read_csv('data/yelp_academic_dataset_review.csv')
biz = pd.read_csv('data/yelp_academic_dataset_business.csv')[['business_id', 'name']]

reviews = pd.merge(reviews, biz, how='inner', on='business_id')
# Out:
# CPU times: user 43.2 s, sys: 11.1 s, total: 54.3 s
# Wall time: 1min 1s

# %%
biz_name = "Five Guys Burgers and Fries"
biz_reviews = reviews[reviews['name'] == biz_name][['text', 'stars']]

# %%
reviews['name'].value_counts()
# Out:
# Starbucks                                           15595
# Hash House A Go Go                                   8351
# McDonald's                                           6601
# Chipotle Mexican Grill                               6544
# Mon Ami Gabi                                         6414
# Bacchanal Buffet                                     5715
# Wicked Spoon                                         5216
# Gordon Ramsay BurGR                                  5116
# Earl of Sandwich                                     5044
# Buffalo Wild Wings                                   4928
# In-N-Out Burger                                      4437
# Gangnam Asian BBQ Dining                             4120
# Serendipity 3                                        3911
# The Buffet                                           3822
# Pita Jungle                                          3749
# Egg Works                                            3746
# Bachi Burger                                         3695
# Dunkin' Donuts                                       3603
# Subway                                               3572
# Five Guys Burgers and Fries                          3549
# Panera Bread                                         3548
# The Cheesecake Factory                               3532
# Oregano's Pizza Bistro                               3529
# Denny's                                              3484
# The Buffet at Bellagio                               3482
# Lotus of Siam                                        3458
# The Cosmopolitan of Las Vegas                        3400
# ARIA Resort & Casino                                 3385
# Smashburger                                          3352
# Walmart Supercenter                                  3317
#                                                     ...
# Bella Vista Luxury Apartments                           3
# Illuminati                                              3
# To Go Foodbar                                           3
# Asia Court                                              3
# Stewart Brewing                                         3
# Footlocker                                              3
# Dare Insurance Agency Inc                               3
# Planet Fitness - Kent                                   3
# Commerce Court                                          3
# Longniddry Inn                                          3
# Rc Hobby                                                3
# Veterinary Emergency Clinic Of Gaston County, PA        3
# Gilmore's Family Garage                                 3
# Fun City Motel                                          3
# The Gaming Goat                                         3
# High Climbers Tree Removal Service                      3
# Redefine Laser Spa                                      3
# Lighting & Bulbs Unlimited                              3
# Bargain Nook                                            3
# Excel Defense Studios                                   3
# Piedmont Springs Apartments                             3
# Quench Nail Bar                                         3
# Elite Massage & Spa                                     3
# ProBox Portable Storage                                 3
# Team Universal Muay Thai                                3
# Christensen Family Chiropractic                         3
# Grand Luxe                                              3
# Manila Oriental Foodmart                                3
# Unique Signs USA                                        3
# Costco Anjou                                            3
# Name: name, dtype: int64

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=300, ngram_range=(1, 3))
model = LinearRegression() 

large_sample = reviews.sample(100000)
corpus = large_sample['text'].values
X = tfidf.fit_transform(corpus)

y = large_sample['stars'].values
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Get the 10 highest and the 10 lowest weights indices 
max_indices = heapq.nlargest(100, range(len(model.coef_)), key=model.coef_.__getitem__)
min_indices = heapq.nsmallest(100, range(len(model.coef_)), key=model.coef_.__getitem__)

def print_summary(indices):
    features = tfidf.get_feature_names()
    for i in indices:
        feat = features[i]
        print('{} ({}): {:.2f}'.format(feat, tfidf.vocabulary_[feat], model.coef_[i]))

print('Business summary: ' + biz_name + '\n')
print_summary(max_indices)
print('----------')
print_summary(reversed(min_indices))
# Out:
# Business summary: Five Guys Burgers and Fries
#
# amazing (7): 1.98
# great (113): 1.83
# best (19): 1.81
# delicious (63): 1.70
# excellent (85): 1.66
# awesome (14): 1.66
# perfect (191): 1.52
# fantastic (90): 1.42
# wonderful (292): 1.35
# love (159): 1.34
# happy (119): 1.28
# favorite (93): 1.24
# friendly (104): 1.23
# definitely (62): 1.19
# helpful (123): 1.18
# loved (160): 1.18
# highly (125): 1.18
# able (4): 1.00
# needed (173): 0.94
# enjoyed (83): 0.76
# vegas (274): 0.75
# really good (208): 0.74
# fast (92): 0.73
# fresh (101): 0.72
# right (216): 0.70
# feel (94): 0.69
# guys (116): 0.69
# quick (205): 0.67
# years (297): 0.65
# yelp (298): 0.63
# nice (175): 0.62
# clean (40): 0.61
# family (89): 0.61
# super (246): 0.60
# tasty (254): 0.58
# fun (107): 0.57
# try (268): 0.54
# enjoy (82): 0.53
# free (100): 0.52
# house (132): 0.52
# cool (48): 0.51
# highly recommend (126): 0.51
# new (174): 0.49
# good (111): 0.47
# sweet (249): 0.47
# huge (133): 0.46
# makes (163): 0.46
# job (140): 0.45
# ve (273): 0.44
# dessert (64): 0.44
# spicy (235): 0.44
# usually (272): 0.43
# town (266): 0.43
# recommend (209): 0.42
# visit (275): 0.42
# chocolate (39): 0.42
# sure (247): 0.40
# stop (243): 0.40
# kind (143): 0.39
# worth (294): 0.38
# strip (245): 0.37
# different (67): 0.37
# yes (299): 0.36
# brought (26): 0.36
# wife (289): 0.34
# home (127): 0.34
# work (293): 0.33
# care (34): 0.32
# course (51): 0.30
# little (151): 0.30
# shop (229): 0.29
# large (145): 0.29
# comes (45): 0.29
# menu (168): 0.28
# pork (199): 0.28
# day (57): 0.27
# friends (105): 0.27
# spot (236): 0.26
# wine (290): 0.25
# looking (157): 0.25
# customer service (54): 0.24
# hot (128): 0.24
# bring (25): 0.23
# year (296): 0.23
# plus (197): 0.23
# need (172): 0.23
# wait (276): 0.22
# lot (158): 0.22
# places (195): 0.22
# area (8): 0.22
# know (144): 0.21
# husband (134): 0.21
# big (21): 0.21
# especially (84): 0.19
# ll (152): 0.17
# oh (177): 0.17
# dishes (72): 0.16
# things (258): 0.16
# friend (103): 0.15
# having (121): 0.15
# ----------
# cheap (35): -0.23
# 10 (0): -0.23
# decided (61): -0.23
# cooked (47): -0.24
# chicken (38): -0.24
# drink (77): -0.24
# small (232): -0.26
# meat (167): -0.26
# thing (257): -0.26
# thought (260): -0.27
# ask (10): -0.27
# eating (80): -0.27
# drinks (78): -0.27
# line (150): -0.27
# hard (120): -0.27
# buffet (27): -0.28
# tried (267): -0.29
# door (76): -0.30
# like (149): -0.30
# want (282): -0.30
# wanted (283): -0.31
# hotel (129): -0.31
# use (270): -0.32
# stars (239): -0.33
# days (58): -0.35
# times (262): -0.35
# tables (251): -0.36
# couldn (49): -0.36
# 15 (1): -0.37
# staff (237): -0.38
# went (288): -0.38
# 20 (2): -0.40
# walked (281): -0.40
# does (73): -0.41
# going (110): -0.43
# place (194): -0.44
# room (217): -0.45
# water (285): -0.46
# isn (138): -0.47
# order (182): -0.48
# did (65): -0.49
# server (227): -0.49
# store (244): -0.50
# probably (203): -0.50
# person (192): -0.51
# away (13): -0.51
# 30 (3): -0.52
# way (286): -0.52
# just (141): -0.52
# flavor (98): -0.53
# later (146): -0.54
# old (179): -0.55
# tell (256): -0.55
# location (153): -0.58
# taste (252): -0.59
# called (31): -0.60
# waiter (277): -0.61
# second (224): -0.62
# hours (131): -0.63
# people (190): -0.64
# used (271): -0.67
# wrong (295): -0.71
# half (118): -0.73
# service (228): -0.74
# trying (269): -0.76
# doesn (74): -0.78
# decent (60): -0.79
# hour (130): -0.79
# better (20): -0.80
# waiting (278): -0.82
# finally (96): -0.84
# ordered (183): -0.86
# business (29): -0.86
# star (238): -0.88
# looked (156): -0.89
# return (212): -0.91
# customer (53): -0.92
# didn (66): -0.93
# maybe (165): -0.93
# food (99): -0.95
# minutes (169): -0.95
# wasn (284): -0.98
# won (291): -1.00
# waitress (279): -1.01
# stay (241): -1.03
# don (75): -1.16
# disappointed (70): -1.20
# instead (137): -1.20
# tasted (253): -1.32
# ok (178): -1.42
# customers (55): -1.45
# cold (43): -1.47
# pay (189): -1.54
# left (147): -1.55
# asked (11): -1.59
# manager (164): -1.63
# said (218): -1.64
# bad (15): -1.74
# told (264): -2.19
# money (170): -2.39
